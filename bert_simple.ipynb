# %%
# %pip install pandas scikit-learn

# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
# import tensorflow as tf
# from tensorflow import keras
# import tensorflow_text as text  # Registers the ops.
# import tensorflow_hub as hub
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 # %pip install pandas scikit-learn
#       2
#       3 # Import Libraries
# ----> 4 import pandas as pd
#       5 import numpy as np
#       6 import seaborn as sns
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:148
#     129 from pandas.core.computation.api import eval
#     131 from pandas.core.reshape.api import (
#     132     concat,
#     133     lreshape,
#    (...)
#     145     qcut,
#     146 )
# --> 148 from pandas import api, arrays, errors, io, plotting, tseries
#     149 from pandas import testing
#     150 from pandas.util._print_versions import show_versions
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps as dumps,
#       5     ujson_loads as loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "dumps",
#      11     "loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\_json.py:67
#      62 from pandas.io.json._normalize import convert_to_line_delimits
#      63 from pandas.io.json._table_schema import (
#      64     build_table_schema,
#      65     parse_table_schema,
#      66 )
# ---> 67 from pandas.io.parsers.readers import validate_integer
#      69 if TYPE_CHECKING:
#      70     from collections.abc import (
#      71         Hashable,
#      72         Mapping,
#      73     )
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:27
#      24 import numpy as np
#      26 from pandas._libs import lib
# ---> 27 from pandas._libs.parsers import STR_NA_VALUES
#      28 from pandas.errors import (
#      29     AbstractMethodError,
#      30     ParserWarning,
#      31 )
#      32 from pandas.util._decorators import Appender
#
# File parsers.pyx:1417, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %% [markdown]
# # Dataset Loading

# %% [markdown]
# #### Loading the datasets from the direct path is important orelse it threw me an error if I downloaded the kaggle datasets and then used them here.

# %%
import pandas

# %%
train_essay = pd.read_csv("Actual-Datasets/train_essays.csv")
train_essay
# Out:
#             id  prompt_id                                               text  \
# 0     0059830c          0  Cars. Cars have been around since they became ...
# 1     005db917          0  Transportation is a large necessity in most co...
# 2     008f63e3          0  "America's love affair with it's vehicles seem...
# 3     00940276          0  How often do you ride in a car? Do you drive a...
# 4     00c39458          0  Cars are a wonderful thing. They are perhaps o...
# ...        ...        ...                                                ...
# 1373  fe6ff9a5          1  There has been a fuss about the Elector Colleg...
# 1374  ff669174          0  Limiting car usage has many advantages. Such a...
# 1375  ffa247e0          0  There's a new trend that has been developing f...
# 1376  ffc237e9          0  As we all know cars are a big part of our soci...
# 1377  ffe1ca0d          0  Cars have been around since the 1800's and hav...
#
#       generated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1373          0
# 1374          0
# 1375          0
# 1376          0
# 1377          0
#
# [1378 rows x 4 columns]

# %%
test_essay = pd.read_csv("Actual-Datasets/test_essays.csv")
test_essay
# Out:
#          id  prompt_id          text
# 0  0000aaaa          2  Aaa bbb ccc.
# 1  1111bbbb          3  Bbb ccc ddd.
# 2  2222cccc          4  CCC ddd eee.

# %%
sample_sub = pd.read_csv("Actual-Datasets/test_essays.csv")
sample_sub
# Out:
#          id  prompt_id          text
# 0  0000aaaa          2  Aaa bbb ccc.
# 1  1111bbbb          3  Bbb ccc ddd.
# 2  2222cccc          4  CCC ddd eee.

# %% [markdown]
# # Data Analysis and Visualization

# %%
train_essay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1378 entries, 0 to 1377
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         1378 non-null   object
#  1   prompt_id  1378 non-null   int64
#  2   text       1378 non-null   object
#  3   generated  1378 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 43.2+ KB

# %%
train_essay['prompt_id'].value_counts()
# Out:
# prompt_id
# 0    708
# 1    670
# Name: count, dtype: int64

# %%
sns.countplot(x=train_essay['prompt_id'])
plt.show()

# %%
train_essay['prompt_id'].value_counts().plot(kind="pie",autopct="%.1f%%")
plt.title("Prompt ID")
plt.show()

# %%
train_essay['generated'].value_counts().plot(kind="pie",autopct="%.1f%%") # to see what to take as base
plt.title("Target label")
plt.show()

# %% [markdown]
# #### We observe that wrt 'generated' the data is highly imbalanced so we would be using 'prompt_id'

# %%
train_essay.head()
# Out:
#          id  prompt_id                                               text  \
# 0  0059830c          0  Cars. Cars have been around since they became ...
# 1  005db917          0  Transportation is a large necessity in most co...
# 2  008f63e3          0  "America's love affair with it's vehicles seem...
# 3  00940276          0  How often do you ride in a car? Do you drive a...
# 4  00c39458          0  Cars are a wonderful thing. They are perhaps o...
#
#    generated
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
ai_df = train_essay[train_essay['generated']==1]
ai_df
# Out:
#             id  prompt_id                                               text  \
# 704   82131f68          1  This essay will analyze, discuss and prove one...
# 740   86fe4f18          1  I strongly believe that the Electoral College ...
# 1262  eafb8a56          0  Limiting car use causes pollution, increases c...
#
#       generated
# 704           1
# 740           1
# 1262          1

# %%
train_essay
# Out:
#             id  prompt_id                                               text  \
# 0     0059830c          0  Cars. Cars have been around since they became ...
# 1     005db917          0  Transportation is a large necessity in most co...
# 2     008f63e3          0  "America's love affair with it's vehicles seem...
# 3     00940276          0  How often do you ride in a car? Do you drive a...
# 4     00c39458          0  Cars are a wonderful thing. They are perhaps o...
# ...        ...        ...                                                ...
# 1373  fe6ff9a5          1  There has been a fuss about the Elector Colleg...
# 1374  ff669174          0  Limiting car usage has many advantages. Such a...
# 1375  ffa247e0          0  There's a new trend that has been developing f...
# 1376  ffc237e9          0  As we all know cars are a big part of our soci...
# 1377  ffe1ca0d          0  Cars have been around since the 1800's and hav...
#
#       generated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1373          0
# 1374          0
# 1375          0
# 1376          0
# 1377          0
#
# [1378 rows x 4 columns]

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ### we would be using the stopwords_text and then we would be splitting them and all these words would be removed from the essays we had earlier

# %%
stopwords_text = """"i me my myself we our ours ourselves you you're you've you'll you'd your yours yourself yourselves he him his himself she she's her hers herself it it's its itself they them their theirs themselves what which who whom this that that'll these those am is are was were be been being have has had having do does did doing a an the and but if or because as until while of at by for with about against between into through during before after above below to from up down in out on off over under again further then once here there when where why how all any both each few more most other some such only own same so than too very s t can will just don don't should should've now d ll m o re ve y ain aren aren't couldn couldn't didn didn't doesn doesn't hadn hadn't hasn hasn't haven haven't isn isn't ma mightn mightn't mustn mustn't needn needn't shan shan't shouldn shouldn't wasn wasn't weren weren't won won't wouldn wouldn't"
"""
stopwords_list = stopwords_text.split()

# %%
len(stopwords_list)
# Out:
# 176

# %% [markdown]
# # Using custom datasets to feed in more data

# %% [markdown]
# #### this was done to make the model train better with wide variety of data

# %%
df = pd.read_csv("Actual-Datasets/Training_Essay_Data.csv")

# %%
df
# Out:
#                                                     text  generated
# 0      Car-free cities have become a subject of incre...          1
# 1      Car Free Cities  Car-free cities, a concept ga...          1
# 2        A Sustainable Urban Future  Car-free cities ...          1
# 3        Pioneering Sustainable Urban Living  In an e...          1
# 4        The Path to Sustainable Urban Living  In an ...          1
# ...                                                  ...        ...
# 29140  There has been a fuss about the Elector Colleg...          0
# 29141  Limiting car usage has many advantages. Such a...          0
# 29142  There's a new trend that has been developing f...          0
# 29143  As we all know cars are a big part of our soci...          0
# 29144  Cars have been around since the 1800's and hav...          0
#
# [29145 rows x 2 columns]

# %%
df2 = pd.read_csv("Extra-Datasets-Used/train_drcat_01.csv")
df2 = df2[['text','label']]
df2.columns = ['text','generated']
df2
# Out:
#                                                     text  generated
# 0      There are alot reasons to keep our the despise...          0
# 1      Driving smart cars that drive by themself has ...          0
# 2      Dear Principal,\n\nI believe that students at ...          0
# 3      Dear Principal,\n\nCommunity service should no...          0
# 4      My argument for the development of the driverl...          0
# ...                                                  ...        ...
# 33254  Are driverless cars really necessary? Most of ...          0
# 33255  "Oh man I didn't make the soccer team!", yelle...          0
# 33256  I believe that using this technology could be ...          0
# 33257  Texting & Driving\n\nUsing your phone while dr...          0
# 33258  Dear Principal,\n\nI have been really good thi...          0
#
# [33259 rows x 2 columns]

# %%
df2.drop_duplicates(inplace=True,ignore_index=True)

# %%
df2
# Out:
#                                                     text  generated
# 0      There are alot reasons to keep our the despise...          0
# 1      Driving smart cars that drive by themself has ...          0
# 2      Dear Principal,\n\nI believe that students at ...          0
# 3      Dear Principal,\n\nCommunity service should no...          0
# 4      My argument for the development of the driverl...          0
# ...                                                  ...        ...
# 33254  Are driverless cars really necessary? Most of ...          0
# 33255  "Oh man I didn't make the soccer team!", yelle...          0
# 33256  I believe that using this technology could be ...          0
# 33257  Texting & Driving\n\nUsing your phone while dr...          0
# 33258  Dear Principal,\n\nI have been really good thi...          0
#
# [33259 rows x 2 columns]

# %%
df3 = pd.read_csv("Actual-Datasets/train_essays.csv")
# df3.columns = ['text','generated']
df3
# Out:
#             id  prompt_id                                               text  \
# 0     0059830c          0  Cars. Cars have been around since they became ...
# 1     005db917          0  Transportation is a large necessity in most co...
# 2     008f63e3          0  "America's love affair with it's vehicles seem...
# 3     00940276          0  How often do you ride in a car? Do you drive a...
# 4     00c39458          0  Cars are a wonderful thing. They are perhaps o...
# ...        ...        ...                                                ...
# 1373  fe6ff9a5          1  There has been a fuss about the Elector Colleg...
# 1374  ff669174          0  Limiting car usage has many advantages. Such a...
# 1375  ffa247e0          0  There's a new trend that has been developing f...
# 1376  ffc237e9          0  As we all know cars are a big part of our soci...
# 1377  ffe1ca0d          0  Cars have been around since the 1800's and hav...
#
#       generated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1373          0
# 1374          0
# 1375          0
# 1376          0
# 1377          0
#
# [1378 rows x 4 columns]

# %%
train_data = pd.concat([df3,df2,df],axis=0,ignore_index=True)
train_data
# Out:
#              id  prompt_id                                               text  \
# 0      0059830c        0.0  Cars. Cars have been around since they became ...
# 1      005db917        0.0  Transportation is a large necessity in most co...
# 2      008f63e3        0.0  "America's love affair with it's vehicles seem...
# 3      00940276        0.0  How often do you ride in a car? Do you drive a...
# 4      00c39458        0.0  Cars are a wonderful thing. They are perhaps o...
# ...         ...        ...                                                ...
# 63777       NaN        NaN  There has been a fuss about the Elector Colleg...
# 63778       NaN        NaN  Limiting car usage has many advantages. Such a...
# 63779       NaN        NaN  There's a new trend that has been developing f...
# 63780       NaN        NaN  As we all know cars are a big part of our soci...
# 63781       NaN        NaN  Cars have been around since the 1800's and hav...
#
#        generated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 63777          0
# 63778          0
# 63779          0
# 63780          0
# 63781          0
#
# [63782 rows x 4 columns]

# %%
train_data.drop_duplicates(inplace=True,ignore_index=True)

# %%
train_data
# Out:
#              id  prompt_id                                               text  \
# 0      0059830c        0.0  Cars. Cars have been around since they became ...
# 1      005db917        0.0  Transportation is a large necessity in most co...
# 2      008f63e3        0.0  "America's love affair with it's vehicles seem...
# 3      00940276        0.0  How often do you ride in a car? Do you drive a...
# 4      00c39458        0.0  Cars are a wonderful thing. They are perhaps o...
# ...         ...        ...                                                ...
# 58353       NaN        NaN  Today's society is ever-evolving and the role ...
# 58354       NaN        NaN  The ever-evolving world of technology has chan...
# 58355       NaN        NaN  Fostering a Rescue Dog: Gaining Unconditional ...
# 58356       NaN        NaN  The importance of a solid foundation in educat...
# 58357       NaN        NaN  Over the last decade, cities around the world ...
#
#        generated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 58353          1
# 58354          1
# 58355          1
# 58356          1
# 58357          1
#
# [58358 rows x 4 columns]

# %%
# Dataset
d1 = pd.read_csv("Extra-Datasets-Used/falcon_180b_v1.csv")
d1
# Out:
#                                          generated_text  \
# 0     Dear Principal,\n\nI am writing to express my ...
# 1     When people are faced with a difficult decisio...
# 2     As a grade 12 student, I believe that summer p...
# 3     Dear Principal,\n\nI am writing to share my th...
# 4     "Making Mona Lisa Smile" is an interesting art...
# ...                                                 ...
# 1050  (I am not capable of personal opinions or beli...
# 1051  In "The Challenge of Exploring Venus," the aut...
# 1052  The article "Making Mona Lisa Smile" discusses...
# 1053  As a grade 6 student, I am still learning abou...
# 1054  Passage 1:\n\nCars are one of the main ways in...
#
#                                          writing_prompt
# 0     Your principal is considering changing school ...
# 1     When people ask for advice, they sometimes tal...
# 2     Some schools require students to complete summ...
# 3     Some of your friends perform community service...
# 4     In the article "Making Mona Lisa Smile," the a...
# ...                                                 ...
# 1050  The role of zoos in conservation and education...
# 1051  In "The Challenge of Exploring Venus," the aut...
# 1052  In the article "Making Mona Lisa Smile," the a...
# 1053  The issue of gun control is a highly contentio...
# 1054  Write an explanatory essay to inform fellow ci...
#
# [1055 rows x 2 columns]

# %%
# Dataset
d2 = pd.read_csv("Extra-Datasets-Used/llama_70b_v1.csv")
d2
# Out:
#                                          generated_text  \
# 0     Dear State Senator,\n\nI'm writting to you tod...
# 1     Uh, hi! So, like, summers are, like, awesome r...
# 2     When peoples ask for advices, they sometimes t...
# 3     I think art edukation is super impotent for ki...
# 4     I think we should totally switch to renewable ...
# ...                                                 ...
# 1167  Climate change is a really important issue tha...
# 1168  Introduction:\n\nDriverless cars, a technology...
# 1169  Social media has become an integral part of ou...
# 1170  Meat, it's something that many of us have grow...
# 1171  The legalization of marijuana has been a topic...
#
#                                          writing_prompt
# 0     Write a letter to your state senator in which ...
# 1     Some schools require students to complete summ...
# 2     When people ask for advice, they sometimes tal...
# 3     Many people believe that arts education is ess...
# 4     In recent years, there has been a push towards...
# ...                                                 ...
# 1167  The issue of climate change has become increas...
# 1168  In the article “Driverless Cars are Coming,” t...
# 1169  The impact of social media on society has been...
# 1170  There is a growing movement advocating for the...
# 1171  The legalization of marijuana has been a contr...
#
# [1172 rows x 2 columns]

# %%
data = pd.concat([d1,d2],axis=0,ignore_index=True)
data['generated'] = 1
data.columns = ['text','writing_prompt','generated']
data = data[['text','generated']]
data
# Out:
#                                                    text  generated
# 0     Dear Principal,\n\nI am writing to express my ...          1
# 1     When people are faced with a difficult decisio...          1
# 2     As a grade 12 student, I believe that summer p...          1
# 3     Dear Principal,\n\nI am writing to share my th...          1
# 4     "Making Mona Lisa Smile" is an interesting art...          1
# ...                                                 ...        ...
# 2222  Climate change is a really important issue tha...          1
# 2223  Introduction:\n\nDriverless cars, a technology...          1
# 2224  Social media has become an integral part of ou...          1
# 2225  Meat, it's something that many of us have grow...          1
# 2226  The legalization of marijuana has been a topic...          1
#
# [2227 rows x 2 columns]

# %%
Train_Data = pd.concat([train_data,data],axis=0,ignore_index=True)
Train_Data
# Out:
#              id  prompt_id                                               text  \
# 0      0059830c        0.0  Cars. Cars have been around since they became ...
# 1      005db917        0.0  Transportation is a large necessity in most co...
# 2      008f63e3        0.0  "America's love affair with it's vehicles seem...
# 3      00940276        0.0  How often do you ride in a car? Do you drive a...
# 4      00c39458        0.0  Cars are a wonderful thing. They are perhaps o...
# ...         ...        ...                                                ...
# 60580       NaN        NaN  Climate change is a really important issue tha...
# 60581       NaN        NaN  Introduction:\n\nDriverless cars, a technology...
# 60582       NaN        NaN  Social media has become an integral part of ou...
# 60583       NaN        NaN  Meat, it's something that many of us have grow...
# 60584       NaN        NaN  The legalization of marijuana has been a topic...
#
#        generated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 60580          1
# 60581          1
# 60582          1
# 60583          1
# 60584          1
#
# [60585 rows x 4 columns]

# %%
d = pd.read_csv("Extra-Datasets-Used/LLM_generated_essay_PaLM.csv")
d
# Out:
#         id  prompt_id                                               text  \
# 0        0        0.0  ## The Advantages of Limiting Car Usage\n\nIn ...
# 1        1        0.0  The United States is a car-dependent nation, w...
# 2        2        0.0  In recent years, there has been a growing move...
# 3        3        0.0  In recent years, there has been a growing move...
# 4        4        0.0  In the past few decades, the United States has...
# ...    ...        ...                                                ...
# 1379  1379        1.0  Dear Senator,\n\nI am writing to you today to ...
# 1380  1380        1.0  Dear Senator,\n\nI am writing to you today to ...
# 1381  1381        1.0  Dear Senator,\n\nI am writing to you today to ...
# 1382  1382        1.0  Dear Senator,\n\nI am writing to you today to ...
# 1383  1383        1.0  Dear Senator,\n\nI am writing to you today to ...
#
#       generated
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# ...         ...
# 1379        1.0
# 1380        1.0
# 1381        1.0
# 1382        1.0
# 1383        1.0
#
# [1384 rows x 4 columns]

# %%
d['generated'] = d['generated'].astype(int)

# %%
dd = d[['text','generated']]
dd
# Out:
#                                                    text  generated
# 0     ## The Advantages of Limiting Car Usage\n\nIn ...          1
# 1     The United States is a car-dependent nation, w...          1
# 2     In recent years, there has been a growing move...          1
# 3     In recent years, there has been a growing move...          1
# 4     In the past few decades, the United States has...          1
# ...                                                 ...        ...
# 1379  Dear Senator,\n\nI am writing to you today to ...          1
# 1380  Dear Senator,\n\nI am writing to you today to ...          1
# 1381  Dear Senator,\n\nI am writing to you today to ...          1
# 1382  Dear Senator,\n\nI am writing to you today to ...          1
# 1383  Dear Senator,\n\nI am writing to you today to ...          1
#
# [1384 rows x 2 columns]

# %%
Train_Data =pd.concat([train_data,dd],axis=0,ignore_index=True)
Train_Data
# Out:
#              id  prompt_id                                               text  \
# 0      0059830c        0.0  Cars. Cars have been around since they became ...
# 1      005db917        0.0  Transportation is a large necessity in most co...
# 2      008f63e3        0.0  "America's love affair with it's vehicles seem...
# 3      00940276        0.0  How often do you ride in a car? Do you drive a...
# 4      00c39458        0.0  Cars are a wonderful thing. They are perhaps o...
# ...         ...        ...                                                ...
# 59737       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59738       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59739       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59740       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59741       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
#
#        generated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 59737          1
# 59738          1
# 59739          1
# 59740          1
# 59741          1
#
# [59742 rows x 4 columns]

# %%
Train_Data.drop_duplicates(inplace=True,ignore_index=True)

# %%
Train_Data
# Out:
#              id  prompt_id                                               text  \
# 0      0059830c        0.0  Cars. Cars have been around since they became ...
# 1      005db917        0.0  Transportation is a large necessity in most co...
# 2      008f63e3        0.0  "America's love affair with it's vehicles seem...
# 3      00940276        0.0  How often do you ride in a car? Do you drive a...
# 4      00c39458        0.0  Cars are a wonderful thing. They are perhaps o...
# ...         ...        ...                                                ...
# 59737       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59738       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59739       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59740       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
# 59741       NaN        NaN  Dear Senator,\n\nI am writing to you today to ...
#
#        generated
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 59737          1
# 59738          1
# 59739          1
# 59740          1
# 59741          1
#
# [59742 rows x 4 columns]

# %%
Train_Data['generated'].value_counts()
# Out:
# generated
# 0    39876
# 1    19866
# Name: count, dtype: int64

# %%
Train_Data.generated.value_counts().plot(kind='pie',autopct="%.1f%%")
plt.title("Target Column Distributions")
plt.show()

# %%
sns.countplot(x=Train_Data['generated'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Balancing the dataset

# %%
# function to balance label_counts

def balance_labels(df, label_column='generated'):
    label_counts=df[label_column].value_counts()
    max_count=label_counts.max()
    
    balanced_df=pd.DataFrame()
    
    for label, count in label_counts.items():
        label_subset = df[df[label_column]==label]
        oversampled_subset= label_subset.sample(n=(max_count-count), replace=True, random_state=42)
        balanced_df = pd.concat([balanced_df, label_subset, oversampled_subset], ignore_index=True)
        
    return balanced_df

# %%
# Balance labels in the dataframe
Train_Data=balance_labels(Train_Data)

# %%
Train_Data.generated.value_counts().plot(kind='pie',autopct="%.1f%%")
plt.title("Target Column Distributions")
plt.show()

# %% [markdown]
# # Model Building

# %% [markdown]
# ### first we would be segregating the training dataset we have into train and test datasets

# %%
x_train,x_test,y_train,y_test=train_test_split(Train_Data.text,Train_Data.generated,test_size=0.009,shuffle=True)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (79034,)
# (718,)
# (79034,)
# (718,)

# %%
x_train
# Out:
# 52493    When it comes to the different ways to handle ...
# 25509    Although, traveling and exploring to Venus wou...
# 38419    Having online classes could be so much helpful...
# 15705    When you lower the usage of cars in a certain ...
# 58653    In recent years, there has been a growing move...
#                                ...
# 32806    In "The Challenge of Exploring Venus" the auth...
# 52554    The debate over the use of electronic dictiona...
# 40847    As an eighth-grade student, I believe that com...
# 78026    [Your Name]\n[Your Address]\n[City, State, ZIP...
# 33805    Being able to know what your students are feel...
# Name: text, Length: 79034, dtype: object

# %% [markdown]
# ## Using bert model for predictions

# %%
model_path ="/kaggle/input/bert/tensorflow2/bert-en-uncased-l-12-h-768-a-12/2"
preprocess_path = "/kaggle/input/bert/tensorflow2/en-uncased-preprocess/3/"

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 import tensorflow as tf
#       2 print(tf.__version__)
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py:37
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\context.py:31
#      29 from tensorflow.core.protobuf import config_pb2
#      30 from tensorflow.core.protobuf import rewriter_config_pb2
# ---> 31 from tensorflow.python import pywrap_tfe
#      32 from tensorflow.python import tf2
#      33 from tensorflow.python.client import pywrap_tf_session
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\pywrap_tfe.py:25
#      23 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
#      24 from tensorflow.python import pywrap_tensorflow
# ---> 25 from tensorflow.python._pywrap_tfe import *
#
# ImportError: DLL load failed while importing _pywrap_tfe: The specified procedure could not be found.

# %%
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
preprocessor = hub.KerasLayer(preprocess_path)
encoder_inputs  = preprocessor(text_input) # this is basically the preprocessed text

# %%
## Use BERT Model
encoder = hub.KerasLayer(model_path,trainable=True)
outputs = encoder(encoder_inputs)
pooled_output = outputs['pooled_output'] # [batch_size, 512].
sequence_output = outputs["sequence_output"] # [batch_size, seq_length, 512].

# %%
dropout = tf.keras.layers.Dropout(0.51 , name="dropout1")(pooled_output)
dense_2 = tf.keras.layers.Dense(64 , activation='relu')(dropout)
dropout = tf.keras.layers.Dropout(0.3 , name="dropout2")(dense_2)

dense_out = tf.keras.layers.Dense(1 , activation='sigmoid', name='output')(dropout)

model = tf.keras.Model(inputs=text_input, outputs=dense_out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None,)]                    0         []
#
#  keras_layer (KerasLayer)    {'input_word_ids': (None,    0         ['input_1[0][0]']
#                              128),
#                               'input_type_ids': (None,
#                              128),
#                               'input_mask': (None, 128)
#                              }
#
#  keras_layer_1 (KerasLayer)  {'default': (None, 768),     1094822   ['keras_layer[0][0]',
#                               'pooled_output': (None, 7   41         'keras_layer[0][1]',
#                              68),                                    'keras_layer[0][2]']
#                               'sequence_output': (None,
#                               128, 768),
#                               'encoder_outputs': [(None
#                              , 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768)]}
#
#  dropout1 (Dropout)          (None, 768)                  0         ['keras_layer_1[0][13]']
#
#  dense (Dense)               (None, 64)                   49216     ['dropout1[0][0]']
#
#  dropout2 (Dropout)          (None, 64)                   0         ['dense[0][0]']
#
#  output (Dense)              (None, 1)                    65        ['dropout2[0][0]']
#
# ==================================================================================================
# Total params: 109531522 (417.83 MB)
# Trainable params: 109531521 (417.83 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________

# %%
#model.compile(optimizer='adam', loss='binary_crossentropy',metrics=["accuracy"]) # using adam gave better results as compared to rmse
#history = model.fit(x_train, y_train , batch_size=512 , epochs=10 , validation_data=(x_test, y_test)) 
# using smaller batch size gave better predictions as it improved accuracy but the submission accuracy reduced

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
              loss='binary_crossentropy',
              metrics=["acc"])

checkpoint_filepath = 'checkpoint.hdf5'
metric = 'val_accuracy'
callback_list = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, monitor=metric,
                    verbose=2, save_best_only=True, mode='max')
history = model.fit(x_train, y_train , batch_size=8, callbacks=[callback_list],epochs=1 , validation_data=(x_test, y_test))
# model.load_weights(checkpoint_filepath)
model.save("model-bert")
# Out:
# 10222/10222 [==============================] - 2519s 241ms/step - loss: 0.1094 - acc: 0.9585 - val_loss: 0.0917 - val_acc: 0.9771

# %%
loss , acc = model.evaluate(x_train, y_train)
print("Accuracy on Train data:",acc)
loss , acc = model.evaluate(x_test, y_test)
print("Accuracy on Test data:",acc)
# Out:
# 2556/2556 [==============================] - 864s 338ms/step - loss: 0.0565 - acc: 0.9810
# Accuracy on Train data: 0.9809589982032776
# 24/24 [==============================] - 8s 325ms/step - loss: 0.0917 - acc: 0.9771
# Accuracy on Test data: 0.9771198034286499

# %%
test_essay
# Out:
#          id  prompt_id          text
# 0  0000aaaa          2  Aaa bbb ccc.
# 1  1111bbbb          3  Bbb ccc ddd.
# 2  2222cccc          4  CCC ddd eee.

# %% [markdown]
# # Predictions

# %%
y_pred = model.predict(test_essay['text'])
# Out:
# 1/1 [==============================] - 1s 860ms/step

# %%
y_pred
# Out:
# array([[0.4002606 ],
#        [0.55465555],
#        [0.64684063]], dtype=float32)

# %%
y_pred[:,0]
# Out:
# array([0.4002606 , 0.55465555, 0.64684063], dtype=float32)

# %% [markdown]
# # Saving the output in a CSV file

# %%
# Assuming 'test_ids' are the IDs of test samples, and 'predictions' are the predicted values
# converting to the format required for submissions
submission = pd.DataFrame({'id': test_essay['id'] , 'generated': y_pred[:,0] })
submission.to_csv('submission.csv', index=False)  # Save the CSV file

# %%
pd.read_csv("/kaggle/working/submission.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.read_csv("Actual-Datasets/final_Accuracy.csv")
#
# NameError: name 'pd' is not defined
